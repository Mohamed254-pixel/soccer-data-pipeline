# %%
import pandas as pd

df = pd.read_csv("/Users/mohamedibrahim/Desktop/soccer-data-pipeline/data/results.csv")

print("Dataset Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# (43281, 9)

# %%
import pandas as pd

df = pd.read_csv("/Users/mohamedibrahim/Desktop/soccer-data-pipeline/data/results.csv")

print(df.shape)
# Out:
# (43281, 9)
